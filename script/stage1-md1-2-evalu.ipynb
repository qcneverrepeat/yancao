# %%
import numpy as np 
import pandas as pd
import cplex # community edition
import matplotlib.pyplot as plt
from sklearn.externals import joblib # 保存及加载变量
# Out:
# Bad key "text.kerning_factor" on line 4 in
# D:\installation\anaconda\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
arg_source = pd.read_csv('D:/jupyter_dir/yancao/data/step1.csv')
arg_source.head()

# 参数和决策变量
price = arg_source['单箱价格'].values
sold = arg_source['上期销售量'].values 
cap = arg_source['产能'].values

sold_obj = 2300   # 目标销量(箱)
price_obj = 40000 # 目标结构(元/箱)
I = price.size

# %%
var = [i for i in map(lambda x: 'x(' + str(x) + ')', list(range(arg_source.shape[0])))] # ['x(0)', 'x(1)', ...]
lp = '' # lp文件内容

# p1: 一次项 x1 x2 x3 ...
p1 = ''
for i in range(len(cap)):
    p1 += ' - %s x(%s)'%((2/sold + I/(125*sold_obj))[i], i)

# p2: 二次项 x1^2 x2^2 ... (已经乘2)
p2 = ''
for i in range(len(cap)):
    p2 += ' + %s x(%s)^2'%((2/(sold**2) + (2*I)/(sold_obj*250)**2)[i], i)

# p3: 交叉二次项 x1x2 x1x3 ... (已经乘2)
p3 = ''
for i in range(len(cap)):
    for j in range(i+1, len(cap)):
        p3 += ' + %s x(%s) * x(%s)'%(4*I/(250*sold_obj)**2,i,j)

lp += ('Minimize\n obj:' + p1 + ' +[' + p2 + p3 + ']/2\n')

# 约束条件

# p4: Σx_i*price - 0.9*price_obj*Σx_i
p4 = ''
for i in range(len(cap)):
    if (price-0.9*price_obj)[i]>=0:
        p4 += '+'
    p4 += ' %s x(%s)'%((price-0.9*price_obj)[i], i)

# p5: Σx_i*price - 1.1*price_obj*Σx_i
p5 = ''
for i in range(len(cap)):
    if (price-1.1*price_obj)[i]>=0:
        p5 += '+'
    p5 += ' %s x(%s)'%((price-1.1*price_obj)[i], i)

lp += '\nSubject To\n'
lp += ' c1: %s >= 0 \n'%(p4)
lp += ' c2: %s <= 0 \n'%(p5)
for i in range(len(cap)):
    lp += ' c%s: x(%s) - Rgc%s = 0\n'%(3+i, i, i)
lp += 'Bounds\n'
for i in range(len(cap)): 
    lp += 'x(%s) Free\n'%i
for i in range(len(cap)): 
    lp += ' 0 <= Rgc%s <= %s \n'%(i, cap[i])
lp += 'General\n'
for i in range(len(cap)): lp += ' %s'%(var[i])
lp += '\nEnd'

with open('write.lp', 'w') as f:
    f.write(lp)

my_prob = cplex.Cplex('write.lp')
# my_prob = cplex.Cplex('lp/配置 1-2.lp')
my_prob.solve()

x = my_prob.solution.get_values()
sold_next = np.array(x, dtype='int')[0:int(len(x)/2)]
sold_next
# Out:
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 71 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.00 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.00 sec. (0.45 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.07 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000     -346.0255              ---
#       0     0     -141.9561    71        0.0000     -141.9561       13     ---
# *     0+    0                         -141.9560     -141.9561             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (8.77 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.06 sec. (8.77 ticks)
# array([    14,    183,    153,    474,     80,   4723,    522,    594,
#          8100,    714,    691,   2825,   1986,    236,   8921,   9222,
#         13351,    381,   6629,     32,     34,     18,    151,   9691,
#        102347,    756,  11343,  66056,  48500,  43582,   2846,  29643,
#          7295,  49851,  15046,   8956,   7819,    455,    111,   1722,
#          1981,   1884,  41968,    572,    619,   1352,     77,   3591,
#          1285,   9929,     77,   4125,   2142,   1679,     39,    135,
#            89,     66,   2843,   1764,   2667,    607,     43,    159,
#           402,    356,    853,    333,   4291,  10114,   6903])

# %%
# 销量偏差百分比
delta_sold = (sold_obj - sold_next.sum()/250)/sold_obj
delta_price = (price_obj - (sold_next*price).sum()/(sold_next.sum()))/price_obj
delta_sale = (sold_obj*price_obj - (sold_next*price).sum()/250)/(sold_obj*price_obj)
delta_change = ((sold_next-sold)/sold).mean()
print('销量偏差：%.2f \n结构偏差：%.2f\n销售额偏差：%.2f\n销量变动程度：%.2f'%(delta_sold, delta_price, delta_sale, delta_change))
# Out:
# 销量偏差：0.01
# 结构偏差：-0.03
# 销售额偏差：-0.02
# 销量变动程度：0.01

# %%
def model(sold_obj, price_obj):
    var = [i for i in map(lambda x: 'x(' + str(x) + ')', list(range(arg_source.shape[0])))] # ['x(0)', 'x(1)', ...]
    lp = '' # lp文件内容

    # p1: 一次项 x1 x2 x3 ...
    p1 = ''
    for i in range(len(cap)):
        p1 += ' - %s x(%s)'%((2/sold + I/(125*sold_obj))[i], i)

    # p2: 二次项 x1^2 x2^2 ... (已经乘2)
    p2 = ''
    for i in range(len(cap)):
        p2 += ' + %s x(%s)^2'%((2/(sold**2) + (2*I)/(sold_obj*250)**2)[i], i)

    # p3: 交叉二次项 x1x2 x1x3 ... (已经乘2)
    p3 = ''
    for i in range(len(cap)):
        for j in range(i+1, len(cap)):
            p3 += ' + %s x(%s) * x(%s)'%(4*I/(250*sold_obj)**2,i,j)

    lp += ('Minimize\n obj:' + p1 + ' +[' + p2 + p3 + ']/2\n')

    # 约束条件

    # p4: Σx_i*price - 0.9*price_obj*Σx_i
    p4 = ''
    for i in range(len(cap)):
        if (price-0.9*price_obj)[i]>=0:
            p4 += '+'
        p4 += ' %s x(%s)'%((price-0.9*price_obj)[i], i)

    # p5: Σx_i*price - 1.1*price_obj*Σx_i
    p5 = ''
    for i in range(len(cap)):
        if (price-1.1*price_obj)[i]>=0:
            p5 += '+'
        p5 += ' %s x(%s)'%((price-1.1*price_obj)[i], i)

    lp += '\nSubject To\n'
    lp += ' c1: %s >= 0 \n'%(p4)
    lp += ' c2: %s <= 0 \n'%(p5)
    for i in range(len(cap)):
        lp += ' c%s: x(%s) - Rgc%s = 0\n'%(3+i, i, i)
    lp += 'Bounds\n'
    for i in range(len(cap)): 
        lp += 'x(%s) Free\n'%i
    for i in range(len(cap)): 
        lp += ' 0 <= Rgc%s <= %s \n'%(i, cap[i])
    lp += 'General\n'
    for i in range(len(cap)): lp += ' %s'%(var[i])
    lp += '\nEnd'

    with open('write.lp', 'w') as f:
        f.write(lp)
    
    my_prob = cplex.Cplex('write.lp')
    try:
        my_prob.solve()
        x = my_prob.solution.get_values()
    except:
        return np.nan, np.nan, np.nan, np.nan
        
    sold_next = np.array(x, dtype='int')[0:int(len(x)/2)]

    # 销量偏差百分比
    delta_sold = (sold_obj - sold_next.sum()/250)/sold_obj
    delta_price = (price_obj - (sold_next*price).sum()/(sold_next.sum()))/price_obj
    delta_sale = (sold_obj*price_obj - (sold_next*price).sum()/250)/(sold_obj*price_obj)
    delta_change = ((sold_next-sold)/sold).mean()
    return delta_sold, delta_price, delta_sale, delta_change

# %%
# 网格调优
ev_set = np.zeros([15,20,4])

for s in range(15):
    for p in range(20):
        ev_set[s,p] = model(sold_obj=100+s*200, price_obj=15000+p*2000)
# Out:
#  objective Q matrix has 5041 nonzeros.
# Presolve time = 0.00 sec. (0.45 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.14 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000     -312.8004              ---
#       0     0     -126.9428    59        0.0000     -126.9428       14     ---
# *     0+    0                         -126.9177     -126.9428             0.02%
# *     0+    0                         -126.9423     -126.9428             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (9.83 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.08 sec. (9.83 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 71 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.01 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.02 sec. (0.45 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.17 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000     -312.8004              ---
#       0     0     -133.4595    62        0.0000     -133.4595       14     ---
# *     0+    0                         -133.4417     -133.4595             0.01%
# *     0+    0                         -133.4586     -133.4595             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (10.10 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.06 sec. (10.10 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 71 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.02 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.02 sec. (0.45 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.20 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000     -312.8004              ---
#       0     0     -137.9424    63        0.0000     -137.9424       14     ---
# *     0+    0                         -137.9264     -137.9424             0.01%
# *     0+    0                         -137.9422     -137.9424             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (10.24 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.09 sec. (10.24 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 72 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.00 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.02 sec. (0.43 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.26 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          -10.3605     -302.9607              ---
#       0     0     -140.2418    63      -10.3605     -140.2418       16     ---
# *     0+    0                         -140.2394     -140.2418             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (8.32 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.06 sec. (8.32 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 72 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.00 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.02 sec. (0.43 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.09 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          -10.3605     -302.9607              ---
#       0     0     -140.2762    64      -10.3605     -140.2762       15     ---
# *     0+    0                         -140.2761     -140.2762             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (8.43 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.06 sec. (8.43 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 72 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.02 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.00 sec. (0.43 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.09 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          -10.3605     -302.9607              ---
#       0     0     -140.2762    64      -10.3605     -140.2762       15     ---
# *     0+    0                         -140.2761     -140.2762             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (8.43 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.06 sec. (8.43 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 72 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.02 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.00 sec. (0.43 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.01 sec. (4.08 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          -10.3605     -302.9607              ---
#       0     0     -140.2762    64      -10.3605     -140.2762       15     ---
# *     0+    0                         -140.2761     -140.2762             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (8.43 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.06 sec. (8.43 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 71 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.02 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.00 sec. (0.45 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.01 sec. (4.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000     -312.8004              ---
#       0     0     -140.2762    64        0.0000     -140.2762       13     ---
# *     0+    0                         -140.2761     -140.2762             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (8.41 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.06 sec. (8.41 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 71 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.00 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.02 sec. (0.45 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (4.25 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000     -312.8004              ---
#       0     0     -139.2716    60        0.0000     -139.2716       14     ---
# *     0+    0                         -139.2659     -139.2716             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (8.44 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.08 sec. (8.44 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 71 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.02 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 71 columns, and 142 nonzeros.
# Reduced MIQP has 0 binaries, 71 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 5041 nonzeros.
# Presolve time = 0.00 sec. (0.45 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.29 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000     -312.8004              ---
#       0     0     -136.7811    56        0.0000     -136.7811       14     ---
# *     0+    0                         -136.7755     -136.7811             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (8.29 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.06 sec. (8.29 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 72 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.00 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 70 columns, and 140 nonzeros.
# Reduced MIQP has 0 binaries, 70 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4900 nonzeros.
# Presolve time = 0.02 sec. (0.43 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.01 sec. (4.39 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                           -7.5221     -305.4908              ---
#       0     0     -133.7234    53       -7.5221     -133.7234       16     ---
# *     0+    0                         -133.7175     -133.7234             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (8.20 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.05 sec. (8.20 ticks)
# Version identifier: 12.10.0.0 | 2019-11-27 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# MIQP Presolve eliminated 71 rows and 73 columns.
# MIQP Presolve modified 2 coefficients.
# Reduced MIQP has 2 rows, 69 columns, and 138 nonzeros.
# Reduced MIQP has 0 binaries, 69 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4761 nonzeros.
# Presolve time = 0.02 sec. (0.59 ticks)
# Tried aggregator 1 time.
# Reduced MIQP has 2 rows, 69 columns, and 138 nonzeros.
# Reduced MIQP has 0 binaries, 69 generals, 0 SOSs, and 0 indicators.
# Reduced MIQP objective Q matrix has 4761 nonzeros.
# Presolve time = 0.02 sec. (0.42 ticks)
# Classifier predicts products in MIQP should be linearized.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (4.15 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          -17.1136     -296.3859              ---
#       0     0     -130.4444    53      -17.1136     -130.4444       15  662.23%
# *     0+    0                         -130.4387     -130.4444             0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (7.89 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.09 sec. (7.89 ticks)

# %%
joblib.dump(ev_set, '../dump/ev_set_md1-2.pydata')
# Out:
# ['../dump/ev_set_md1-2.pydata']

# %%
# 可视化delta_sold, delta_price, delta_sale, delta_change

hm_data = pd.DataFrame(ev_set[:,:,3])
hm_data.index = [100+s*200 for s in range(15)]
hm_data.columns = Y = [15000+p*2000 for p in range(20)]

import seaborn as sns
fig, ax = plt.subplots(figsize = (23,9))
sns.heatmap(hm_data, annot=True, vmax=0.2,vmin = -0.2, xticklabels= True,yticklabels= True, square=True, cmap="YlGnBu")

ax.set_title('md 1.2 : delta_change')
ax.set_ylabel('sold_obj', fontsize = 18)
ax.set_xlabel('price_obj', fontsize = 18)
# Out:
# Text(0.5, 60.0, 'price_obj')
