# %%
from sklearn.externals import joblib
import pandas as pd
import numpy as np

# %%
retail = joblib.load('D:\\master\\二期工作\\产品投放\\零售户聚类\\retail.pydata')
retail.shape
# Out:
# (3367, 20)

# %%
retail = retail[retail['LATQ'] <= 37.09]
retail = retail[retail['LATQ'] >= 35.35]
retail = retail[retail['LNGQ'] >= 119.3]
retail = retail[retail['LNGQ'] <= 121.0]

# %%
retail.shape
# Out:
# (3094, 20)

# %%
joblib.dump(retail, 'qd_retail.pydata')
# Out:
# ['qd_retail.pydata']
