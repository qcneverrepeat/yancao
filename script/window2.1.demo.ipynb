# %%
re = pd.read_csv('yancao/data/random.csv')
re
# Out:
#               品规ID          品规名
# 0    6901028157629       泰山(拂光)
# 1    6901028159692       泰山(普照)
# 2    6901028148481       泰山(好客)
# 3    6901028150286       泰山(儒风)
# 4    6901028148603     泰山(拂光细支)
# 5    6901028148764       泰山(领秀)
# 6    6901028156820       泰山(乐章)
# 7    6901028156677       泰山(将军)
# 8    6901028150194       泰山(新品)
# 9    6901028157087      泰山(硬神秀)
# 10   6901028156721       泰山(八喜)
# 11   6901028159609       泰山(红秀)
# 12   6901028154048      泰山(红锡包)
# 13   6901028154154     泰山(好客细支)
# 14   6901028150378       泰山(望岳)
# 15   6901028159722       泰山(颜悦)
# 16   6901028157803      泰山(硬功勋)
# 17   6901028159753       泰山(心悦)
# 18   6901028153898       泰山(大鸡)
# 19   6901028147828      泰山(新东方)
# 20   6901028159579       泰山(青秀)
# 21   6901028153171      泰山(绿孔府)
# 22   6901028157834       泰山(沂蒙)
# 23   6901028156752       泰山(东方)
# 24   6901028157216       泰山(宏图)
# 25   6901028148955       泰山(平安)
# 26   6901028156783       泰山(华贵)
# 27   6901028151634      泰山(白将军)
# ...

# %%
import pandas as pd 
import numpy as np

# %%
de = re.sample(replace=False, n=20)
de # 缺货品规
# Out:
#               品规ID        品规名
# 247  6901028025560    娇子(软阳光)
# 271  6901028100960    长白山(香魁)
# 305  4902210249704     七星(天蓝)
# 266  6901028936750     好猫(长乐)
# 186  6901028179324   黄鹤楼(硬珍品)
# 242  6901028220507  娇子(红天之娇子)
# 38   6901028074148    中华(大中华)
# 211  6901028194600  芙蓉王(蔚蓝星空)
# 143  6901028137492     七匹狼(红)
# 163  6901028136389     金圣(庐山)
# 37   6901028076265   熊猫(硬时代版)
# 294  6901028086981       冬虫夏草
# 228  6901028003469     双喜(花悦)
# 310  8801116005581     爱喜(幻变)
# 286  6901028104050  哈尔滨(龙烟金安)
# 78   6901028048682   玉溪(软小庄园)
# 274  6901028099783    长白山(神韵)
# 312  8801116006458     爱喜(薄荷)
# 229  6901028003056  双喜(硬金五叶神)
# 296  8888075005463    555(弘博)

# %%
re.index
de.index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5c11333d5548> in <module>
# ----> 1 re.index-de.index
#
# D:\installation\anaconda\lib\site-packages\pandas\core\indexes\range.py in _evaluate_numeric_binop(self, other)
#     638                     return op(self._int64index, other)
#     639
# --> 640                 other = self._validate_for_numeric_binop(other, op)
#     641                 attrs = self._get_attributes_dict()
#     642                 attrs = self._maybe_update_attributes(attrs)
#
# D:\installation\anaconda\lib\site-packages\pandas\core\indexes\base.py in _validate_for_numeric_binop(self, other, op)
#    5084         if isinstance(other, (Index, ABCSeries, np.ndarray)):
#    5085             if len(self) != len(other):
# -> 5086                 raise ValueError("cannot evaluate a numeric op with "
# ...
