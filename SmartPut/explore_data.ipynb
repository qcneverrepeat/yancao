# %%
import pandas as pd 
import numpy as np

# %%
root = 'D:/master/二期工作/产品投放/数据/项目模型需要的数据/4个表--信息中心/'
sale = pd.read_csv(root+'2018-2019销售明细.csv', encoding='gbk')
cus = pd.read_excel(root+'客户信息表.xlsx', dtype={'客户ID':np.int32})
toba = pd.read_excel(root+'商品信息表.xlsx')

# %%
import re
